# %%
import pandas as pd
import numpy as np

# %%
specs_df = pd.read_csv("../data/raw/gpu_specs/specs.csv")

benchmarks_df = pd.read_csv("../data/raw/gpu_benchmarks/benchmarks.csv")

api_df = pd.read_csv("../data/raw/gpu_api_scores/api_scores.csv")

# %%
specs_df.head()
benchmarks_df.head()
api_df.head()
# Out:
#   Manufacturer               Device      CUDA  Metal    OpenCL    Vulkan
# 0       Nvidia  GeForce RTX 3090 Ti  260346.0    NaN  229738.0  141134.0
# 1       Nvidia       A100 80GB PCIe  259828.0    NaN  214586.0       NaN
# 2       Nvidia       A100-PCIE-80GB  256292.0    NaN  207124.0       NaN
# 3       Nvidia     GeForce RTX 3090  238123.0    NaN  204921.0  138859.0
# 4       Nvidia       A100-SXM4-40GB  237220.0    NaN  190489.0       NaN

# %%
specs_df.info()
benchmarks_df.info()
api_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3056 entries, 0 to 3055
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   manufacturer   3056 non-null   str
#  1   productName    3056 non-null   str
#  2   releaseYear    3012 non-null   float64
#  3   memSize        2615 non-null   float64
#  4   memBusWidth    188 non-null    float64
#  5   gpuClock       3056 non-null   int64
#  6   memClock       2615 non-null   float64
#  7   unifiedShader  2232 non-null   float64
#  8   tmu            3056 non-null   int64
#  9   rop            3056 non-null   int64
#  10  pixelShader    824 non-null    float64
#  11  vertexShader   824 non-null    float64
#  12  igp            3056 non-null   str
#  13  bus            3056 non-null   str
#  14  memType        2615 non-null   str
#  15  gpuChip        3056 non-null   str
# dtypes: float64(7), int64(3), str(6)
# memory usage: 382.1 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 2317 entries, 0 to 2316
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gpuName           2317 non-null   str
#  1   G3Dmark           2317 non-null   int64
#  2   G2Dmark           2317 non-null   int64
#  3   price             553 non-null    float64
#  4   gpuValue          553 non-null    float64
#  5   TDP               692 non-null    float64
#  6   powerPerformance  692 non-null    float64
#  7   testDate          2317 non-null   int64
#  8   category          2317 non-null   str
# dtypes: float64(4), int64(3), str(2)
# memory usage: 163.0 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 1213 entries, 0 to 1212
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Manufacturer  1213 non-null   str
#  1   Device        1213 non-null   str
#  2   CUDA          266 non-null    float64
#  3   Metal         241 non-null    float64
#  4   OpenCL        976 non-null    float64
#  5   Vulkan        629 non-null    float64
# dtypes: float64(4), str(2)
# memory usage: 57.0 KB

# %%
specs_df.columns
benchmarks_df.columns
api_df.columns
# Out:
# Index(['Manufacturer', 'Device', 'CUDA', 'Metal', 'OpenCL', 'Vulkan'], dtype='str')

# %%
specs_df.isnull().sum()
benchmarks_df.isnull().sum()
api_df.isnull().sum()
# Out:
# Manufacturer      0
# Device            0
# CUDA            947
# Metal           972
# OpenCL          237
# Vulkan          584
# dtype: int64

# %%
specs_df.duplicated().sum()
benchmarks_df.duplicated().sum()
api_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
def clean_column_names(df):
    df.columns = (
        df.columns
        .str.strip()
        .str.lower()
        .str.replace(" ", "_")
        .str.replace("-", "_")
    )
    return df

# %%
specs_df = clean_column_names(specs_df)

benchmarks_df = clean_column_names(benchmarks_df)

api_df = clean_column_names(api_df)

# %%
print(specs_df.columns.tolist())
# Out:
# ['manufacturer', 'gpu_name', 'releaseyear', 'memsize', 'membuswidth', 'gpuclock', 'memclock', 'unifiedshader', 'tmu', 'rop', 'pixelshader', 'vertexshader', 'igp', 'bus', 'memtype', 'gpuchip']

# %%
print(benchmarks_df.columns.tolist())
# Out:
# ['gpu_name', 'g3dmark', 'g2dmark', 'price', 'gpuvalue', 'tdp', 'powerperformance', 'testdate', 'category']

# %%
print(api_df.columns.tolist())
# Out:
# ['manufacturer', 'gpu_name', 'cuda', 'metal', 'opencl', 'vulkan']

# %%
specs_df = specs_df.rename(
    columns={"productname": "gpu_name"}
)

benchmarks_df = benchmarks_df.rename(
    columns={"gpuname": "gpu_name"}
)

api_df = api_df.rename(
    columns={"device": "gpu_name"}
)

# %%
specs_df["gpu_name"].head(10)
# Out:
# 0                  GEFORCE RTX 5090
# 1                  GEFORCE RTX 5080
# 2                  GEFORCE RTX 5070
# 3           GEFORCE RTX 5060 MOBILE
# 4                  GEFORCE RTX 5060
# 5                  GEFORCE RTX 5050
# 6    RTX 1000 MOBILE ADA GENERATION
# 7             GEFORCE RTX 3050 6 GB
# 8            RADEON INSTINCT MI325X
# 9                          RTX A400
# Name: gpu_name, dtype: str

# %%
benchmarks_df["gpu_name"].head(10)
# Out:
# 0    GEFORCE RTX 3090 TI
# 1    GEFORCE RTX 3080 TI
# 2       GEFORCE RTX 3090
# 3      RADEON RX 6900 XT
# 4       GEFORCE RTX 3080
# 5    GEFORCE RTX 3070 TI
# 6      RADEON RX 6800 XT
# 7              RTX A5000
# 8              RTX A6000
# 9       GEFORCE RTX 3070
# Name: gpu_name, dtype: str

# %%
api_df["gpu_name"].head(10)
# Out:
# 0            GEFORCE RTX 3090 TI
# 1                 A100 80GB PCIE
# 2                 A100-PCIE-80GB
# 3               GEFORCE RTX 3090
# 4                 A100-SXM4-40GB
# 5            GEFORCE RTX 3080 TI
# 6    GRID A100-7-40C MIG 7G.40GB
# 7                      RTX A6000
# 8                   GRID A100-4C
# 9          TESLA V100S-PCIE-32GB
# Name: gpu_name, dtype: str

# %%
specs_df["gpu_name"].nunique()
# Out:
# 2733

# %%
benchmarks_df["gpu_name"].nunique()
# Out:
# 2317

# %%
api_df["gpu_name"].nunique()
# Out:
# 1212

# %%
specs_df["gpu_name"].duplicated().sum()
# Out:
# np.int64(323)

# %%
benchmarks_df["gpu_name"].duplicated().sum()
# Out:
# np.int64(0)

# %%
api_df["gpu_name"].duplicated().sum()
# Out:
# np.int64(1)

# %%
print("Specs:", specs_df.shape)
print("Benchmarks:", benchmarks_df.shape)
print("API:", api_df.shape)
# Out:
# Specs: (3056, 16)
# Benchmarks: (2317, 9)
# API: (1213, 6)

# %%
specs_df.isnull().sum()
# Out:
# manufacturer        0
# gpu_name            0
# releaseyear        44
# memsize           441
# membuswidth      2868
# gpuclock            0
# memclock          441
# unifiedshader     824
# tmu                 0
# rop                 0
# pixelshader      2232
# vertexshader     2232
# igp                 0
# bus                 0
# memtype           441
# gpuchip             0
# dtype: int64

# %%
benchmarks_df.isnull().sum()
# Out:
# gpu_name               0
# g3dmark                0
# g2dmark                0
# price               1764
# gpuvalue            1764
# tdp                 1625
# powerperformance    1625
# testdate               0
# category               0
# dtype: int64

# %%
api_df.isnull().sum()
# Out:
# manufacturer      0
# gpu_name          0
# cuda            947
# metal           972
# opencl          237
# vulkan          584
# dtype: int64

# %%
specs_df["gpu_name"] = specs_df["gpu_name"].str.strip()

benchmarks_df["gpu_name"] = benchmarks_df["gpu_name"].str.strip()

api_df["gpu_name"] = api_df["gpu_name"].str.strip()

# %%
specs_df["gpu_name"] = specs_df["gpu_name"].str.upper()

benchmarks_df["gpu_name"] = benchmarks_df["gpu_name"].str.upper()

api_df["gpu_name"] = api_df["gpu_name"].str.upper()

# %%
common_specs_bench = set(specs_df["gpu_name"]).intersection(
    set(benchmarks_df["gpu_name"])
)

print("Common GPUs:", len(common_specs_bench))
# Out:
# Common GPUs: 1028

# %%
common_bench_api = set(benchmarks_df["gpu_name"]).intersection(
    set(api_df["gpu_name"])
)

print("Common GPUs:", len(common_bench_api))
# Out:
# Common GPUs: 646

# %%
master_df = pd.merge(
    specs_df,
    benchmarks_df,
    on="gpu_name",
    how="inner"
)

# %%
master_df.shape
# Out:
# (1173, 24)

# %%
master_df.head()
# Out:
#   manufacturer             gpu_name  releaseyear  memsize  membuswidth  \
# 0          AMD    RADEON RX 6500 XT       2022.0      4.0         64.0
# 1          AMD       RADEON RX 6400       2022.0      4.0         64.0
# 2          AMD     RADEON PRO W6400       2022.0      4.0         64.0
# 3       NVIDIA  GEFORCE RTX 3090 TI       2022.0     24.0        384.0
# 4          AMD      RADEON RX 6700S       2022.0      8.0        128.0
#
#    gpuclock  memclock  unifiedshader  tmu  rop  ...  memtype  gpuchip g3dmark  \
# 0      1560    1313.0        10752.0  336  112  ...   GDDR6X    GA102    9445
# 1      1395    1219.0        10496.0  328  112  ...   GDDR6X    GA102    6958
# 2      1080    2000.0        10240.0  320   96  ...    GDDR6    GA102    5916
# 3      1980    1313.0         7168.0  224   80  ...   GDDR6X    AD104   29094
# 4      1440     945.0         4096.0  256   64  ...     HBM2  Vega 10   11989
#
#   g2dmark    price gpuvalue    tdp  powerperformance  testdate  category
# 0     910   199.99    47.23    NaN               NaN      2022   Unknown
# 1     899   159.99    43.49    NaN               NaN      2022   Unknown
# 2     621      NaN      NaN    NaN               NaN      2022   Unknown
# 3    1117  2099.99    13.85  450.0             64.65      2022   Unknown
# 4     829      NaN      NaN    NaN               NaN      2022   Unknown
#
# [5 rows x 24 columns]

# %%
master_df.isnull().sum()
# Out:
# manufacturer           0
# gpu_name               0
# releaseyear            0
# memsize               70
# membuswidth         1168
# gpuclock               0
# memclock             203
# unifiedshader        225
# tmu                    0
# rop                    0
# pixelshader          948
# vertexshader         948
# igp                    0
# bus                    0
# memtype              203
# gpuchip                0
# g3dmark                0
# g2dmark                0
# price                698
# gpuvalue             698
# tdp                  573
# powerperformance     573
# testdate               0
# category               0
# dtype: int64

# %%
master_df = pd.merge(
    master_df,
    api_df,
    on="gpu_name",
    how="left"
)

# %%
master_df.shape
# Out:
# (1174, 29)

# %%
master_df.isnull().sum()
# Out:
# manufacturer_x         0
# gpu_name               0
# releaseyear            0
# memsize               70
# membuswidth         1169
# gpuclock               0
# memclock             203
# unifiedshader        225
# tmu                    0
# rop                    0
# pixelshader          949
# vertexshader         949
# igp                    0
# bus                    0
# memtype              203
# gpuchip                0
# g3dmark                0
# g2dmark                0
# price                698
# gpuvalue             698
# tdp                  573
# powerperformance     573
# testdate               0
# category               0
# manufacturer_y       640
# cuda                 995
# metal               1044
# opencl               652
# vulkan               873
# dtype: int64

# %%
master_df.to_csv(
    "../data/processed/master_gpu_dataset.csv",
    index=False
)
